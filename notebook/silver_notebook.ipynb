# %%
# importação das libs
import pandas as pd
from IPython.utils import path

# %%
products_path = '../raw_files/olist_products_dataset.csv'
df_products = pd.read_csv(products_path)
print(df_products.info())
print(df_products.head().to_string())

# %%
total_nulos = df_products['product_category_name'].isna().sum()
print(total_nulos)
# Out:
# 610

# %%
# Ler dados de Pedidos
path= '../raw_files/olist_order_payments_dataset.csv'
df_pay = pd.read_csv(path)
print(df_pay.info())

# %%
print(df_pay.head().to_string())
# Out:
#                            order_id  payment_sequential payment_type  payment_installments  payment_value
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card                     8          99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card                     1          24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card                     1          65.71
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card                     8         107.78
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card                     2         128.45

# %%
# from pandas import col

# df_nulos = df_pay.filter(col("sua_coluna").isNull())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/projetos/ml/olist/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
# Ler dados de Pedidos
path= '../raw_files/olist_orders_dataset.csv'
df_order = pd.read_csv(path)
print(df_order.info())

# %%
len(df_order)
# Out:
# 99441

# %%
len(df_order[df_order['order_approved_at'].isna()])
# Out:
# 160

# %%
# remover pedidos sem data de aprovação
df_order = df_order.dropna(subset=['order_approved_at'])

# %%
len(df_order)
# Out:
# 99281

# %%
timestamp_cols = [
    'order_approved_at',
    'order_purchase_timestamp',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
]

for column in timestamp_cols:
    df_order[column] = pd.to_datetime(df_order[column])

# %%
df_order['ingestion_at'] = pd.Timestamp.now()

# %%
df_order.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 99281 entries, 0 to 99440
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99281 non-null  str
#  1   customer_id                    99281 non-null  str
#  2   order_status                   99281 non-null  str
#  3   order_purchase_timestamp       99281 non-null  datetime64[us]
#  4   order_approved_at              99281 non-null  datetime64[us]
#  5   order_delivered_carrier_date   97644 non-null  datetime64[us]
#  6   order_delivered_customer_date  96462 non-null  datetime64[us]
#  7   order_estimated_delivery_date  99281 non-null  datetime64[us]
#  8   ingestion_at                   99281 non-null  datetime64[us]
# dtypes: datetime64[us](6), str(3)
# memory usage: 7.6 MB
